# %% [markdown]
# <a href="https://colab.research.google.com/github/dylanj141/Dylan-Johnson-Data-110/blob/main/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('visual studio is better and is free')
# Out:
# visual studio is better and is free

# %%
print(3*2+43/12)
# Out:
# 9.583333333333334

# %%
x = [1,2,3,4]
y = [12, 32, 57, 79]
print(x)
print(y)
# Out:
# [1, 2, 3, 4]
# [12, 32, 57, 79]

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
